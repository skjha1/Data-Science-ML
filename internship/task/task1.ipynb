# %%
import pandas as pd

# %%
df = pd.read_csv(r'H:/extra/wpforms-491-MEMBER-DETAILS-2020-12-09-06-22-14.csv')

# %%
df
# Out:
#                       Name  REGISTRATION NO         Phone  \
# 0          Himesh Sankhala  RA1611003020540    7358545508
# 1              ravi ranjan  RA1611003020581    8789731953
# 2            Abhiraj Yadav  RA1711003020244    8630992281
# 3           Abhishek Ghosh  RA1811003020464    9647230197
# 4    V.M.Navaneet Krishnan  RA1911026020018    8072094483
# ..                     ...              ...           ...
# 105           FARAZUL HODA  RA1811003020603  919798811749
# 106         ASHUTOSH KASAT  RA1611003020565    7276637981
# 107    SHIVENDRA KUMAR JHA  RA1811003020152    8969599129
# 108      Sowmith Chakilela  RA1611003020530    7893591843
# 109         ABHISHEK ghosh  RA1811003020464    9647230197
#
#                             Email  \
# 0     himeshsankhala123@gmail.com
# 1                 ravi@dhobig.com
# 2            ah5404@srmist.edu.in
# 3          abhighosh257@gmail.com
# 4    navaneetkrishnan10@gmail.com
# ..                            ...
# ...
